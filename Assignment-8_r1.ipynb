# %% [markdown]
# <a href="https://colab.research.google.com/github/cdelcristo/BD101/blob/master/Assignment-8_r1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
#import dataset
data = pd.read_csv('https://raw.githubusercontent.com/cdelcristo/BD101/master/Data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0     fea.1     fea.2     fea.3  ...   fea.254   fea.255  fea.256  gnd
# 0           1 -1.000000 -0.999977 -0.998420  ... -0.931514 -0.992336 -0.99966    0
# 1           2 -1.000000 -0.999998 -0.999760  ... -0.999839 -0.999998 -1.00000    0
# 2           3 -0.999999 -0.999970 -0.999545  ... -0.999056 -0.999990 -1.00000    0
# 3           4 -1.000000 -1.000000 -0.999878  ... -0.993412 -0.999916 -1.00000    0
# 4           5 -1.000000 -1.000000 -0.999999  ... -1.000000 -1.000000 -1.00000    0
#
# [5 rows x 258 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Columns: 258 entries, Unnamed: 0 to gnd
# dtypes: float64(256), int64(2)
# memory usage: 1.6 MB

# %%
data.shape
# Out:
# (800, 258)

# %%
data.describe()
# Out:
#        Unnamed: 0       fea.1       fea.2  ...     fea.255     fea.256         gnd
# count    800.0000  800.000000  800.000000  ...  800.000000  800.000000  800.000000
# mean     400.5000   -0.991409   -0.968831  ...   -0.945590   -0.977662    1.500000
# std      231.0844    0.047754    0.118036  ...    0.166216    0.088638    1.118733
# min        1.0000   -1.000000   -1.000000  ...   -1.000000   -1.000000    0.000000
# 25%      200.7500   -1.000000   -1.000000  ...   -1.000000   -1.000000    0.750000
# 50%      400.5000   -1.000000   -0.999974  ...   -0.999896   -0.999998    1.500000
# 75%      600.2500   -0.999922   -0.996333  ...   -0.991112   -0.999377    2.250000
# max      800.0000   -0.342725    0.112006  ...    0.168234   -0.230614    3.000000
#
# [8 rows x 258 columns]

# %%
data.gnd.value_counts()
# Out:
# 3    200
# 2    200
# 1    200
# 0    200
# Name: gnd, dtype: int64

# %%
dataFeatures = data.drop(['gnd','Unnamed: 0'] , axis=1)
dataFeatures.head(2)
# Out:
#    fea.1     fea.2    fea.3     fea.4  ...   fea.253   fea.254   fea.255  fea.256
# 0   -1.0 -0.999977 -0.99842 -0.969256  ... -0.740973 -0.931514 -0.992336 -0.99966
# 1   -1.0 -0.999998 -0.99976 -0.992020  ... -0.993541 -0.999839 -0.999998 -1.00000
#
# [2 rows x 256 columns]

# %%
dataY = data.gnd
dataY.shape
# Out:
# (800,)

# %%
dataFeatures.shape
# Out:
# (800, 256)

# %%
dataY.shape
# Out:
# (800,)

# %%
x_train, x_test, y_train, y_test = train_test_split(dataFeatures, dataY, test_size=0.33, random_state=14)

# %%
lr = LogisticRegression(solver='lbfgs',multi_class='auto', max_iter=500)
lr_baseLine = lr.fit(x_train,y_train)

# %%
accuracyFunc(lr_baseLine,x_test,y_test)
# Out:
# Accuracy is:  0.9886363636363636
# F1 score is:  0.9886363636363636
# 1

# %%
rfe = RFE(estimator=lr, step=1)
rfe = rfe.fit(x_train, y_train)

# %%
selected_rfe_features = pd.DataFrame({'Feature':list(x_train.columns),
                                      'Ranking':rfe.ranking_})
selected_rfe_features.sort_values(by='Ranking').transpose()
# Out:
#              247      102      103      104  ...     79      77      31      15
# Feature  fea.248  fea.103  fea.104  fea.105  ...  fea.80  fea.78  fea.32  fea.16
# Ranking        1        1        1        1  ...     126     127     128     129
#
# [2 rows x 256 columns]

# %%
x_train_rfe = rfe.transform(x_train)
x_test_rfe = rfe.transform(x_test)

# %%
x_train_rfe.shape
# Out:
# (536, 128)

# %%
x_test_rfe.shape
# Out:
# (264, 128)

# %%
lr_rfe = lr.fit(x_train_rfe,y_train)

# %%
accuracyFunc(lr_rfe, x_test_rfe, y_test)
# Out:
# Accuracy is:  0.9848484848484849
# F1 score is:  0.9848484848484849
# 1

# %%
def accuracyFunc(model, x, y):
#     cm = confusion_matrix(y,model.predict(x))
#     sns.heatmap(cm,annot=True,fmt="d")
    ac = accuracy_score(y,model.predict(x))
    f_score = f1_score(y,model.predict(x),average='micro')
    print('Accuracy is: ', ac)
    print('F1 score is: ', f_score)
    return 1
